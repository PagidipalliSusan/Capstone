# %%
import pandas as pd
import random
from faker import Faker
import string
from datetime import timedelta

fake = Faker()

# Function to generate a random 10-character alphanumeric string
def generate_id(length=10):
    return ''.join(random.choices(string.ascii_uppercase + string.digits, k=length))

# Country to currency and city mapping
country_currency_mapping = {
    'United States': {'currency': 'USD', 'cities': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']},
    'India': {'currency': 'INR', 'cities': ['Delhi', 'Mumbai', 'Hyderabad', 'Chennai', 'Bangalore']},
    'United Kingdom': {'currency': 'GBP', 'cities': ['London', 'Birmingham', 'Manchester', 'Glasgow', 'Liverpool']},
    'Japan': {'currency': 'JPY', 'cities': ['Tokyo', 'Osaka', 'Nagoya', 'Sapporo', 'Fukuoka']},
    'Germany': {'currency': 'EUR', 'cities': ['Berlin', 'Hamburg', 'Munich', 'Cologne', 'Frankfurt']},
}

# Generate random country not in the list
def generate_anomalous_country():
    return ''.join(random.choices(string.ascii_uppercase + string.digits, k=7))

# Customer data generation
def generate_customers(num_customers, anomaly_percentage):
    customers = []
    countries = list(country_currency_mapping.keys())
    num_anomalies = int(num_customers * anomaly_percentage / 100)

    for i in range(num_customers):
        customer_id = generate_id()
        first_name = fake.first_name()
        last_name = fake.last_name()
        date_of_birth = fake.date_of_birth(minimum_age=18, maximum_age=90)
        gender = random.choice(['Male', 'Female'])
        email = fake.email()
        phone_number = fake.phone_number()
        address = fake.street_address()
        
        # Introduce anomalies in country
        if i < num_anomalies // 2:
            country = generate_anomalous_country()  # Anomalous country
            city = "Unknown"
        else:
            country = random.choice(countries)
            city = random.choice(country_currency_mapping[country]['cities'])

        # Introduce uncleansed data
        if i < num_anomalies // 4:
            date_of_birth = fake.date_of_birth(minimum_age=150, maximum_age=200)  # Invalid age
        elif i < num_anomalies // 4 * 2:
            first_name = f"{first_name}#$!"
        elif i < num_anomalies // 4 * 3:
            last_name = None  # Null last_name
        elif i < num_anomalies // 4 * 4:
            date_of_birth = None  # Null date_of_birth

        occupation = fake.job()
        income_bracket = random.choice(['Low', 'Medium', 'High'])
        customer_since = fake.date_between(start_date='-2y', end_date='now')

        customers.append({
            'customer_id': customer_id,
            'first_name': first_name,
            'last_name': last_name,
            'date_of_birth': date_of_birth,
            'gender': gender,
            'email': email,
            'phone_number': phone_number,
            'address': address,
            'city': city,
            'country': country,
            'occupation': occupation,
            'income_bracket': income_bracket,
            'customer_since': customer_since
        })

    return pd.DataFrame(customers)

# Account data generation
def generate_accounts(customers_df):
    accounts = []
    account_types = ['checking', 'savings', 'credit card', 'loan']
    account_statuses = ['active', 'dormant', 'closed']

    for _, customer in customers_df.iterrows():
        for _ in range(random.randint(1, 3)):  # Each customer can have 1 to 3 accounts
            account_id = generate_id()
            customer_id = customer['customer_id']
            account_type = random.choice(account_types)
            account_status = random.choice(account_statuses)
            open_date = fake.date_between(start_date=customer['customer_since'])
            current_balance = round(random.uniform(0.0, 100000.0), 2)
            currency = country_currency_mapping.get(customer['country'], {'currency': 'USD'})['currency']
            credit_limit = round(random.uniform(1000.0, 50000.0), 2) if account_type == 'credit card' else 0.0

            accounts.append({
                'account_id': account_id,
                'customer_id': customer_id,
                'account_type': account_type,
                'account_status': account_status,
                'open_date': open_date,
                'current_balance': current_balance,
                'currency': currency,
                'credit_limit': credit_limit
            })

    return pd.DataFrame(accounts)

# Transaction data generation with anomalies
def generate_transaction_data(num_transactions, customers_df, accounts_df, anomaly_percentage):
    transactions = []
    channels = ['online', 'mobile', 'ATM', 'in-branch']
    transaction_types = ['purchase', 'transfer', 'withdrawal', 'deposit']
    merchants = ['Amazon', 'Walmart', 'Target', 'Best Buy', 'Costco']
    categories = ['Retail', 'Grocery', 'Electronics', 'Clothing', 'Miscellaneous']
    
    num_anomalies = int(num_transactions * anomaly_percentage / 100)
    anomaly_counter = 0

    for i in range(num_transactions):
        customer = customers_df.sample(1).iloc[0]
        account = accounts_df[accounts_df['customer_id'] == customer['customer_id']].sample(1).iloc[0]
        transaction_id = generate_id()
        customer_id = customer['customer_id']
        transaction_date = fake.date_time_between(start_date='-2y', end_date='now')
        amount = round(random.uniform(1.0, 10000.0), 2)
        country_info = country_currency_mapping.get(customer['country'], {'currency': 'USD', 'cities': ['New York']})
        currency = country_info['currency']
        transaction_type = random.choice(transaction_types)
        channel = random.choice(channels)
        merchant_name = random.choice(merchants)
        merchant_category = random.choice(categories)
        location_country = customer['country']
        location_city = random.choice(country_info['cities'])
        is_flagged = False

        # Introduce transaction anomalies
        if anomaly_counter < num_anomalies:
            if anomaly_counter < num_anomalies // 3:
                if transaction_type == 'purchase':
                    amount = round(random.uniform(200000.0, 500000.0), 2)  # High-value purchase anomaly
                    is_flagged = True
            elif anomaly_counter < num_anomalies // 3 * 2:
                if transaction_type == 'transfer':
                    amount = round(random.uniform(100000.0, 300000.0), 2)  # High-value transfer anomaly
                    is_flagged = True
            else:
                if transaction_type == 'withdrawal':
                    same_customer_withdrawals = transactions[-5:]  # Get the last 5 transactions
                    if all(t['transaction_type'] == 'withdrawal' and 
                           t['customer_id'] == customer_id and 
                           (transaction_date - t['transaction_date']).total_seconds() <= 600
                           for t in same_customer_withdrawals):
                        is_flagged = True  # Flagged due to frequent withdrawals
            anomaly_counter += 1

        transactions.append({
            'transaction_id': transaction_id,
            'customer_id': customer_id,
            'transaction_date': transaction_date,
            'amount': amount,
            'currency': currency,
            'transaction_type': transaction_type,
            'channel': channel,
            'merchant_name': merchant_name,
            'merchant_category': merchant_category,
            'location_country': location_country,
            'location_city': location_city,
            'is_flagged': is_flagged
        })

    return pd.DataFrame(transactions)

# Credit data generation
def generate_credit_data(customers_df):
    credit_data = []
    for _, customer in customers_df.iterrows():
        credit_score = random.randint(300, 850)
        number_of_credit_accounts = random.randint(1, 10)
        total_credit_limit = round(random.uniform(1000.0, 50000.0), 2)
        total_credit_used = round(random.uniform(0.0, total_credit_limit), 2)
        number_of_late_payments = random.randint(0, 5)
        bankruptcies = random.randint(0, 1)

        credit_data.append({
            'customer_id': customer['customer_id'],
            'credit_score': credit_score,
            'number_of_credit_accounts': number_of_credit_accounts,
            'total_credit_limit': total_credit_limit,
            'total_credit_used': total_credit_used,
            'number_of_late_payments': number_of_late_payments,
            'bankruptcies': bankruptcies
        })

    return pd.DataFrame(credit_data)

# Generate all data
def generate_data(num_customers, num_transactions, anomaly_percentage):
    customers_df = generate_customers(num_customers, anomaly_percentage)
    accounts_df = generate_accounts(customers_df)
    transactions_df = generate_transaction_data(num_transactions, customers_df, accounts_df, anomaly_percentage)
    credit_data_df = generate_credit_data(customers_df)
    
    return customers_df, accounts_df, transactions_df, credit_data_df

# Save data to CSV
def save_data_to_csv(customers_df, accounts_df, transactions_df, credit_data_df):
    customers_df.to_csv('C:/snowflake1/data/customers.csv', index=False)
    accounts_df.to_csv('C:/snowflake1/data/accounts.csv', index=False)
    transactions_df.to_csv('C:/snowflake1/data/transactions.csv', index=False)
    credit_data_df.to_csv('C:/snowflake1/data/credit_data.csv', index=False)

# Main function
if __name__ == "__main__":
    num_customers = 100  # Number of customers
    num_transactions = 1000  # Number of transactions
    anomaly_percentage = 5  # Percentage of anomalies and uncleansed data

    customers_df, accounts_df, transactions_df, credit_data_df = generate_data(num_customers, num_transactions, anomaly_percentage)
    save_data_to_csv(customers_df, accounts_df, transactions_df, credit_data_df)

# %%
pip install apache-airflow
# Out:
# Requirement already satisfied: apache-airflow in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (2.9.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: alembic<2.0,>=1.13.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.13.2)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.4.0)
# Requirement already satisfied: asgiref in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.8.1)
# Requirement already satisfied: attrs>=22.1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (23.1.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.6.2)
# Requirement already satisfied: colorlog<5.0,>=4.0.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (4.8.0)
# Requirement already satisfied: configupdater>=3.1.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.2)
# Requirement already satisfied: connexion<3.0,>=2.10.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from connexion[flask]<3.0,>=2.10.0->apache-airflow) (2.14.2)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.4.3)
# Requirement already satisfied: croniter>=2.0.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.0.3)
# Requirement already satisfied: cryptography>=39.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (42.0.2)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.2.14)
# Requirement already satisfied: dill>=0.2.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.3.7)
# Requirement already satisfied: flask-caching>=1.5.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.3.0)
# Requirement already satisfied: flask-session<0.6,>=0.4.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.5.0)
# Requirement already satisfied: flask-wtf>=0.15 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.2.1)
# Requirement already satisfied: flask<2.3,>=2.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.2.5)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2023.10.0)
# Requirement already satisfied: google-re2>=1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.1.20240702)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (22.0.0)
# Requirement already satisfied: httpx in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.27.0)
# Requirement already satisfied: importlib_metadata>=6.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (6.11.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.0.1)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.1.3)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (4.19.2)
# Requirement already satisfied: lazy-object-proxy in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.6.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.0.0)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.12.2)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.2.0)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.1.3)
# Requirement already satisfied: marshmallow-oneofschema>=2.0.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.1.1)
# Requirement already satisfied: mdit-py-plugins>=0.3.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.3.0)
# Requirement already satisfied: methodtools>=0.4.7 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.26.0)
# Requirement already satisfied: packaging>=14.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (23.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.10.3)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.0.0)
# Requirement already satisfied: pluggy>=1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.0.0)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (5.9.0)
# Requirement already satisfied: pygments>=2.0.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.15.1)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: python-daemon>=3.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.8.2)
# Requirement already satisfied: python-nvd3>=0.15.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.16.0)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (5.0.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.31.0)
# Requirement already satisfied: rfc3339-validator>=0.1.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.1.4)
# Requirement already satisfied: rich-argparse>=1.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.5.2)
# Requirement already satisfied: rich>=12.4.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (13.3.5)
# Requirement already satisfied: setproctitle>=1.1.8 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.3.3)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.36 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.4.53)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.0.2)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=6.2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (8.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.4.0)
# Requirement already satisfied: unicodecsv>=0.14.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.14.1)
# Requirement already satisfied: universal-pathlib>=0.2.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (0.2.2)
# Requirement already satisfied: werkzeug<3,>=2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (2.2.3)
# Requirement already satisfied: apache-airflow-providers-common-io in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.3.2)
# Requirement already satisfied: apache-airflow-providers-common-sql in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.14.2)
# Requirement already satisfied: apache-airflow-providers-fab>=1.0.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.2.1)
# Requirement already satisfied: apache-airflow-providers-ftp in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.10.0)
# Requirement already satisfied: apache-airflow-providers-http in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (4.12.0)
# Requirement already satisfied: apache-airflow-providers-imap in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.6.1)
# Requirement already satisfied: apache-airflow-providers-smtp in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (1.7.1)
# Requirement already satisfied: apache-airflow-providers-sqlite in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow) (3.8.1)
# Requirement already satisfied: Mako in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow) (4.9.0)
# Requirement already satisfied: flask-appbuilder==4.5.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.5.0)
# Requirement already satisfied: flask-login>=0.6.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.6.3)
# Requirement already satisfied: jmespath>=0.7.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-fab>=1.0.2->apache-airflow) (1.0.1)
# Requirement already satisfied: apispec<7,>=6.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.6.1)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.4.6)
# Requirement already satisfied: click<9,>=8 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (8.1.7)
# Requirement already satisfied: email-validator>=1.0.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.2.0)
# Requirement already satisfied: Flask-Babel<3,>=1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.0.0)
# Requirement already satisfied: Flask-Limiter<4,>3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.8.0)
# Requirement already satisfied: Flask-SQLAlchemy<3,>=2.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.5.1)
# Requirement already satisfied: Flask-JWT-Extended<5.0.0,>=4.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.6.0)
# Requirement already satisfied: marshmallow<4,>=3.18.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.21.3)
# Requirement already satisfied: marshmallow-sqlalchemy<0.29.0,>=0.22.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.28.2)
# Requirement already satisfied: prison<1.0.0,>=0.2.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.2.1)
# Requirement already satisfied: sqlalchemy-utils<1,>=0.32.21 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (0.41.2)
# Requirement already satisfied: WTForms<4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.1.2)
# Requirement already satisfied: clickclick<21,>=1.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow) (20.10.2)
# Requirement already satisfied: PyYAML<7,>=5.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow) (6.0.1)
# Requirement already satisfied: inflection<0.6,>=0.3.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow) (0.5.1)
# Requirement already satisfied: pytz>2021.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from croniter>=2.0.2->apache-airflow) (2023.3.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from cryptography>=39.0.0->apache-airflow) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.1)
# Requirement already satisfied: cachelib<0.10.0,>=0.9.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from flask-caching>=1.5.0->apache-airflow) (0.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from importlib_metadata>=6.5->apache-airflow) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->apache-airflow) (0.10.6)
# Requirement already satisfied: uc-micro-py in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from markdown-it-py>=2.1.0->apache-airflow) (0.1.0)
# Requirement already satisfied: wirerope>=0.4.7 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from methodtools>=0.4.7->apache-airflow) (0.4.7)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow) (2023.3)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow) (2.14.2)
# Requirement already satisfied: docutils in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow) (0.18.1)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from python-daemon>=3.0.0->apache-airflow) (68.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27.0->apache-airflow) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4.36->apache-airflow) (3.0.1)
# Requirement already satisfied: more-itertools>=9.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow) (10.1.0)
# Requirement already satisfied: sqlparse>=0.4.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.5.1)
# Requirement already satisfied: aiohttp>=3.9.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (3.9.3)
# Requirement already satisfied: requests_toolbelt in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from apache-airflow-providers-http->apache-airflow) (1.0.0)
# Requirement already satisfied: anyio in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from httpx->apache-airflow) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from httpx->apache-airflow) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from httpcore==1.*->httpx->apache-airflow) (0.14.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.26.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.26.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp->apache-airflow) (1.26.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (1.63.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (1.65.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk~=1.26.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (1.26.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (4.25.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow) (1.9.3)
# Requirement already satisfied: pycparser in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=39.0.0->apache-airflow) (2.21)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from email-validator>=1.0.5->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.6.1)
# Requirement already satisfied: Babel>=2.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (2.11.0)
# Requirement already satisfied: limits>=3.13 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (3.13.0)
# Requirement already satisfied: ordered-set<5,>4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (4.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.26.0->opentelemetry-exporter-otlp-proto-grpc==1.26.0->opentelemetry-exporter-otlp->apache-airflow) (0.47b0)
# Requirement already satisfied: importlib-resources>=1.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from limits>=3.13->Flask-Limiter<4,>3->flask-appbuilder==4.5.0->apache-airflow-providers-fab>=1.0.2->apache-airflow) (6.4.0)

# %%
pip install dbt-core
# Out:
# Collecting dbt-coreNote: you may need to restart the kernel to use updated packages.
#
#   Downloading dbt_core-1.8.4-py3-none-any.whl.metadata (3.9 kB)
# Collecting agate<1.10,>=1.7.0 (from dbt-core)
#   Downloading agate-1.9.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Jinja2<4,>=3.1.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (3.1.3)
# Collecting mashumaro<4.0,>=3.9 (from mashumaro[msgpack]<4.0,>=3.9->dbt-core)
#   Downloading mashumaro-3.13.1-py3-none-any.whl.metadata (114 kB)
#      ---------------------------------------- 0.0/114.3 kB ? eta -:--:--
#      --------- --------------------------- 30.7/114.3 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 114.3/114.3 kB 1.3 MB/s eta 0:00:00
# Collecting logbook<1.6,>=1.5 (from dbt-core)
#   Downloading Logbook-1.5.3.tar.gz (85 kB)
#      ---------------------------------------- 0.0/85.8 kB ? eta -:--:--
#      ---------------------------------------- 85.8/85.8 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: click<9.0,>=8.0.2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (8.1.7)
# Requirement already satisfied: networkx<4.0,>=2.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (3.1)
# Collecting protobuf<5,>=4.0.0 (from dbt-core)
#   Downloading protobuf-4.25.4-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3.0.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (2.31.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (0.10.3)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (0.5.1)
# Collecting dbt-extractor<=0.6,>=0.5.0 (from dbt-core)
#   Downloading dbt_extractor-0.5.1-cp38-abi3-win_amd64.whl.metadata (4.3 kB)
# Collecting minimal-snowplow-tracker<0.1,>=0.0.2 (from dbt-core)
#   Downloading minimal-snowplow-tracker-0.0.2.tar.gz (12 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dbt-semantic-interfaces<0.6,>=0.5.1 (from dbt-core)
#   Downloading dbt_semantic_interfaces-0.5.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting dbt-common<2.0,>=1.0.4 (from dbt-core)
#   Downloading dbt_common-1.7.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting dbt-adapters<2.0,>=1.1.1 (from dbt-core)
#   Downloading dbt_adapters-1.4.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>20.9 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (23.1)
# Requirement already satisfied: pytz>=2015.7 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (2023.3.post1)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (6.0.1)
# Collecting daff>=1.3.46 (from dbt-core)
#   Downloading daff-1.3.46.tar.gz (149 kB)
#      ---------------------------------------- 0.0/149.8 kB ? eta -:--:--
#      -------------------------------------- 149.8/149.8 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: typing-extensions>=4.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-core) (4.9.0)
# Requirement already satisfied: Babel>=2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from agate<1.10,>=1.7.0->dbt-core) (2.11.0)
# Collecting isodate>=0.5.4 (from agate<1.10,>=1.7.0->dbt-core)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting leather>=0.3.2 (from agate<1.10,>=1.7.0->dbt-core)
#   Downloading leather-0.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting parsedatetime!=2.5,>=2.1 (from agate<1.10,>=1.7.0->dbt-core)
#   Downloading parsedatetime-2.6-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-slugify>=1.2.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from agate<1.10,>=1.7.0->dbt-core) (5.0.2)
# Collecting pytimeparse>=1.1.5 (from agate<1.10,>=1.7.0->dbt-core)
#   Downloading pytimeparse-1.1.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: tzdata>=2023.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from agate<1.10,>=1.7.0->dbt-core) (2023.3)
# Requirement already satisfied: colorama in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from click<9.0,>=8.0.2->dbt-core) (0.4.6)
# Collecting deepdiff<8.0,>=7.0 (from dbt-common<2.0,>=1.0.4->dbt-core)
#   Downloading deepdiff-7.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-common<2.0,>=1.0.4->dbt-core) (4.19.2)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-common<2.0,>=1.0.4->dbt-core) (2.8.2)
# Collecting importlib-metadata<7,>=6.0 (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (10.1.0)
# Requirement already satisfied: pydantic<3,>=1.10 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (1.10.12)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from Jinja2<4,>=3.1.3->dbt-core) (2.1.3)
# Requirement already satisfied: msgpack>=0.5.6 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from mashumaro[msgpack]<4.0,>=3.9->dbt-core) (1.0.3)
# Requirement already satisfied: six<2.0,>=1.9.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from minimal-snowplow-tracker<0.1,>=0.0.2->dbt-core) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0->dbt-core) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0->dbt-core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0->dbt-core) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0->dbt-core) (2024.2.2)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from deepdiff<8.0,>=7.0->dbt-common<2.0,>=1.0.4->dbt-core) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from importlib-metadata<7,>=6.0->dbt-semantic-interfaces<0.6,>=0.5.1->dbt-core) (3.17.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-core) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-core) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-core) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.0.4->dbt-core) (0.10.6)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\susanp\appdata\local\anaconda3\lib\site-packages (from python-slugify>=1.2.1->agate<1.10,>=1.7.0->dbt-core) (1.3)
# Downloading dbt_core-1.8.4-py3-none-any.whl (900 kB)
#    ---------------------------------------- 0.0/900.2 kB ? eta -:--:--
#    --------------------------- ----------- 645.1/900.2 kB 13.5 MB/s eta 0:00:01
#    --------------------------------------- 900.2/900.2 kB 14.4 MB/s eta 0:00:00
# Downloading agate-1.9.1-py2.py3-none-any.whl (95 kB)
#    ---------------------------------------- 0.0/95.1 kB ? eta -:--:--
#    ---------------------------------------- 95.1/95.1 kB 5.7 MB/s eta 0:00:00
# Downloading dbt_adapters-1.4.0-py3-none-any.whl (159 kB)
#    ---------------------------------------- 0.0/159.9 kB ? eta -:--:--
#    ---------------------------------------- 159.9/159.9 kB 9.4 MB/s eta 0:00:00
# Downloading dbt_common-1.7.0-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.1 kB ? eta -:--:--
#    ---------------------------------------- 78.1/78.1 kB 4.2 MB/s eta 0:00:00
# Downloading dbt_extractor-0.5.1-cp38-abi3-win_amd64.whl (283 kB)
#    ---------------------------------------- 0.0/283.5 kB ? eta -:--:--
#    --------------------------------------- 283.5/283.5 kB 17.1 MB/s eta 0:00:00
# Downloading dbt_semantic_interfaces-0.5.1-py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.7 kB ? eta -:--:--
#    ---------------------------------------- 119.7/119.7 kB ? eta 0:00:00
# Downloading mashumaro-3.13.1-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB 5.1 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 12.6 MB/s eta 0:00:00
# Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#    ---------------------------------------- 0.0/80.8 kB ? eta -:--:--
#    ---------------------------------------- 80.8/80.8 kB 4.4 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.1 MB/s eta 0:00:00
# Downloading leather-0.4.0-py2.py3-none-any.whl (30 kB)
# Downloading parsedatetime-2.6-py3-none-any.whl (42 kB)
#    ---------------------------------------- 0.0/42.5 kB ? eta -:--:--
#    ---------------------------------------- 42.5/42.5 kB 2.0 MB/s eta 0:00:00
# Downloading pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: daff, logbook, minimal-snowplow-tracker
#   Building wheel for daff (setup.py): started
#   Building wheel for daff (setup.py): finished with status 'done'
#   Created wheel for daff: filename=daff-1.3.46-py3-none-any.whl size=146125 sha256=f9d45e6cd5ea7a8cee8d8f7815b7e32266bc0f41745b1160780f66cf92a9e6e0
#   Stored in directory: c:\users\susanp\appdata\local\pip\cache\wheels\7b\88\a5\77e082bc529d8146e3931645dcb7481416a68448faedb0dd7e
#   Building wheel for logbook (setup.py): started
#   Building wheel for logbook (setup.py): finished with status 'done'
#   Created wheel for logbook: filename=Logbook-1.5.3-cp311-cp311-win_amd64.whl size=65624 sha256=778e6bc2d35f7ee37d38c3f22e8ddaa1d958051d875bf194b6680a60b808ce24
#   Stored in directory: c:\users\susanp\appdata\local\pip\cache\wheels\41\be\29\54b3065e766f93fd507f7e625311a8deba2842a5f1b060ede4
#   Building wheel for minimal-snowplow-tracker (setup.py): started
#   Building wheel for minimal-snowplow-tracker (setup.py): finished with status 'done'
#   Created wheel for minimal-snowplow-tracker: filename=minimal_snowplow_tracker-0.0.2-py3-none-any.whl size=17820 sha256=882ca1f95fbc21c91f1c0cda854c322021f30deb08b2e8771b8f1cf9c98e776c
#   Stored in directory: c:\users\susanp\appdata\local\pip\cache\wheels\a0\74\73\6bbb925fbe51194cc6436f6efb07f87b31e400a406dd6250f9
# Successfully built daff logbook minimal-snowplow-tracker
# Installing collected packages: pytimeparse, parsedatetime, logbook, leather, daff, protobuf, mashumaro, isodate, importlib-metadata, deepdiff, dbt-extractor, minimal-snowplow-tracker, agate, dbt-semantic-interfaces, dbt-common, dbt-adapters, dbt-core
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# Successfully installed agate-1.9.1 daff-1.3.46 dbt-adapters-1.4.0 dbt-common-1.7.0 dbt-core-1.8.4 dbt-extractor-0.5.1 dbt-semantic-interfaces-0.5.1 deepdiff-7.0.1 importlib-metadata-6.11.0 isodate-0.6.1 leather-0.4.0 logbook-1.5.3 mashumaro-3.13.1 minimal-snowplow-tracker-0.0.2 parsedatetime-2.6 protobuf-4.25.4 pytimeparse-1.1.8
